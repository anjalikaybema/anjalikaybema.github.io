# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


games = pd.read_csv('games.csv')
players = pd.read_csv('players.csv')
plays = pd.read_csv('plays.csv')
# tackels = pd.read_csv('tackles.csv')
first_week = pd.read_csv('tracking_week_1.csv')

# %%
games.loc[((games['homeTeamAbbr'] == 'LA') & (games['visitorTeamAbbr'] == 'BUF')) | ((games['homeTeamAbbr'] == 'BUF') & (games['visitorTeamAbbr'] == 'LA'))]
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0  2022090800    2022     1  09/08/2022        20:20:00           LA             BUF              10                 31

# %%
games
# Out:
#          gameId  season  week    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0    2022090800    2022     1  09/08/2022        20:20:00           LA             BUF              10                 31
# 1    2022091100    2022     1  09/11/2022        13:00:00          ATL              NO              26                 27
# 2    2022091101    2022     1  09/11/2022        13:00:00          CAR             CLE              24                 26
# 3    2022091102    2022     1  09/11/2022        13:00:00          CHI              SF              19                 10
# 4    2022091103    2022     1  09/11/2022        13:00:00          CIN             PIT              20                 23
# 5    2022091104    2022     1  09/11/2022        13:00:00          DET             PHI              35                 38
# 6    2022091105    2022     1  09/11/2022        13:00:00          HOU             IND              20                 20
# ...

# %%
plays
# Out:
#            gameId  playId  ballCarrierId ballCarrierDisplayName                                    playDescription  quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  yardlineNumber gameClock  preSnapHomeScore  preSnapVisitorScore passResult  passLength  penaltyYards  prePenaltyPlayResult  playResult playNullifiedByPenalty  absoluteYardlineNumber offenseFormation  defendersInTheBox  passProbability  preSnapHomeTeamWinProbability  preSnapVisitorTeamWinProbability  homeTeamWinProbabilityAdded  visitorTeamWinProbilityAdded  expectedPoints  expectedPointsAdded foulName1 foulName2  foulNFLId1  foulNFLId2
# ...

# %%
len(plays)
# Out:
# 12486

# %%
plays.loc[plays['gameId'] == 2022100908]
# Out:
#            gameId  playId  ballCarrierId ballCarrierDisplayName                                    playDescription  quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  yardlineNumber gameClock  preSnapHomeScore  preSnapVisitorScore passResult  passLength  penaltyYards  prePenaltyPlayResult  playResult playNullifiedByPenalty  absoluteYardlineNumber offenseFormation  defendersInTheBox  passProbability  preSnapHomeTeamWinProbability  preSnapVisitorTeamWinProbability  homeTeamWinProbabilityAdded  visitorTeamWinProbilityAdded  expectedPoints  expectedPointsAdded                  foulName1 foulName2  foulNFLId1  foulNFLId2
# ...

# %%
first_week.loc[first_week['playId'] == ]
# Out:
#              gameId  playId    nflId     displayName  frameId                        time  jerseyNumber      club playDirection          x      y     s     a   dis       o     dir         event
# 0        2022090800      56  35472.0  Rodger Saffold        1  2022-09-08 20:24:05.200000          76.0       BUF          left  88.370000  27.27  1.62  1.15  0.16  231.74  147.90           NaN
# 1        2022090800      56  35472.0  Rodger Saffold        2  2022-09-08 20:24:05.299999          76.0       BUF          left  88.470000  27.13  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2        2022090800      56  35472.0  Rodger Saffold        3  2022-09-08 20:24:05.400000          76.0       BUF          left  88.560000  27.01  1.57  0.49  0.15  230.98  147.05           NaN
# 3        2022090800      56  35472.0  Rodger Saffold        4  2022-09-08 20:24:05.500000          76.0       BUF          left  88.640000  26.90  1.44  0.89  0.14  232.38  145.42           NaN
# ...

# %%
first_week.loc[first_week['club'] == 'BUF']
# Out:
#            gameId  playId    nflId        displayName  frameId                        time  jerseyNumber club playDirection      x      y     s     a   dis       o     dir         event
# 0      2022090800      56  35472.0     Rodger Saffold        1  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27  1.62  1.15  0.16  231.74  147.90           NaN
# 1      2022090800      56  35472.0     Rodger Saffold        2  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2      2022090800      56  35472.0     Rodger Saffold        3  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01  1.57  0.49  0.15  230.98  147.05           NaN
# 3      2022090800      56  35472.0     Rodger Saffold        4  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90  1.44  0.89  0.14  232.38  145.42           NaN
# ...

# %%
buf = first_week.loc[first_week['club'] == 'BUF']

ids = buf['gameId'].unique()

for id in ids:
    df = first_week.loc[first_week['gameId'] == id]
    print(df['club'].unique())
    if 'BAL' in df['club'].unique():
        print(df.iloc[0])
    else:
        continue
# Out:
# ['BUF' 'LA' 'football']

# %%
first_week.loc[first_week['playId'] == 2184]
# Out:
#            gameId  playId    nflId     displayName  frameId                        time  jerseyNumber      club playDirection          x          y     s     a   dis       o     dir         event
# 43240  2022090800    2184  35472.0  Rodger Saffold        1  2022-09-08 22:01:27.400000          76.0       BUF          left  37.190000  22.050000  1.79  2.80  0.17  286.97   34.95  pass_arrived
# 43241  2022090800    2184  35472.0  Rodger Saffold        2  2022-09-08 22:01:27.500000          76.0       BUF          left  37.260000  22.180000  1.47  3.57  0.14  296.88   23.83           NaN
# 43242  2022090800    2184  35472.0  Rodger Saffold        3  2022-09-08 22:01:27.599999          76.0       BUF          left  37.280000  22.300000  1.21  3.27  0.12  298.55    7.42           NaN
# 43243  2022090800    2184  35472.0  Rodger Saffold        4  2022-09-08 22:01:27.700000          76.0       BUF          left  37.280000  22.400000  1.02  2.82  0.10  298.55  350.77           NaN
# ...

# %%
df = pd.read_csv('tracking_week_1.csv')
df.loc[df['playId'] == 3229]
# Out:
# Empty DataFrame
# Columns: [gameId, playId, nflId, displayName, frameId, time, jerseyNumber, club, playDirection, x, y, s, a, dis, o, dir, event]
# Index: []

# %%
df.loc[df['playId'] == 2056]
# Out:
# Empty DataFrame
# Columns: [gameId, playId, nflId, displayName, frameId, time, jerseyNumber, club, playDirection, x, y, s, a, dis, o, dir, event]
# Index: []

# %%
test = df.loc[df['nflId'] == 47836]
test.loc[df['gameId'] == 2022110300]
# Out:
# Empty DataFrame
# Columns: [gameId, playId, nflId, displayName, frameId, time, jerseyNumber, club, playDirection, x, y, s, a, dis, o, dir, event]
# Index: []
