# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
games = pd.read_csv('games.csv')
players = pd.read_csv('players.csv')
plays = pd.read_csv('plays.csv')
tackels = pd.read_csv('tackles.csv')
first_week = pd.read_csv('tracking_week_1.csv')

# %%
# read in dataframes
df = pd.concat([
    pd.read_csv('tracking_week_1.csv'),
    pd.read_csv('tracking_week_2.csv'),
    pd.read_csv('tracking_week_3.csv'),
    pd.read_csv('tracking_week_4.csv'),
    pd.read_csv('tracking_week_5.csv'),
    pd.read_csv('tracking_week_6.csv'),
    pd.read_csv('tracking_week_7.csv'),
    pd.read_csv('tracking_week_8.csv'),
    pd.read_csv('tracking_week_9.csv'),
])

# %%
test = df.loc[(df['playId'] == 3454) & (df['gameId'] == 2022091101)]
test
# Out:
#             gameId  playId    nflId       displayName  frameId                        time  jerseyNumber      club playDirection           x      y     s     a   dis       o    dir         event
# 250631  2022091101    3454  41227.0  Jadeveon Clowney        1  2022-09-11 15:46:20.599999          90.0       CLE         right   33.110000  27.78  1.97  2.38  0.22  127.27  77.79           NaN
# 250632  2022091101    3454  41227.0  Jadeveon Clowney        2  2022-09-11 15:46:20.700000          90.0       CLE         right   33.290000  27.81  1.81  2.07  0.19  131.38  81.38           NaN
# 250633  2022091101    3454  41227.0  Jadeveon Clowney        3  2022-09-11 15:46:20.799999          90.0       CLE         right   33.500000  27.83  1.82  1.61  0.21  132.15  85.89           NaN
# 250634  2022091101    3454  41227.0  Jadeveon Clowney        4  2022-09-11 15:46:20.900000          90.0       CLE         right   33.700000  27.85  1.84  1.16  0.21  132.15  87.70           NaN
# ...

# %%
# Define the figure size and axis limits
plt.figure(figsize=(14, 6))
plt.xlim(0, 120)
plt.ylim(0, 53.3)
plt.gca().invert_yaxis()  # Invert the y-axis to match the football field orientation

# Plotting the path for the NFLId (simulated as 41227.0)
# In the real scenario, you would iterate over unique nflId values and plot each path
player_data = df.loc[(df['playId'] == 3454) & (df['gameId'] == 2022091101) & (df['nflId'] == 41227.0)]
test

print(player_data)
plt.plot(player_data['x'], player_data['y'], marker='o', linestyle='-', color='blue')

# Add grid, labels, and title
plt.grid(True)
plt.xlabel('X Position (yards)')
plt.ylabel('Y Position (yards)')
plt.title('Player Movement Paths')

# Display the plot
plt.show()
# Out:
#             gameId  playId    nflId       displayName  frameId                        time  jerseyNumber club playDirection      x      y     s     a   dis       o    dir                event
# 250631  2022091101    3454  41227.0  Jadeveon Clowney        1  2022-09-11 15:46:20.599999          90.0  CLE         right  33.11  27.78  1.97  2.38  0.22  127.27  77.79                  NaN
# 250632  2022091101    3454  41227.0  Jadeveon Clowney        2  2022-09-11 15:46:20.700000          90.0  CLE         right  33.29  27.81  1.81  2.07  0.19  131.38  81.38                  NaN
# 250633  2022091101    3454  41227.0  Jadeveon Clowney        3  2022-09-11 15:46:20.799999          90.0  CLE         right  33.50  27.83  1.82  1.61  0.21  132.15  85.89                  NaN
# 250634  2022091101    3454  41227.0  Jadeveon Clowney        4  2022-09-11 15:46:20.900000          90.0  CLE         right  33.70  27.85  1.84  1.16  0.21  132.15  87.70                  NaN
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,1)

unique = test['nflId'].unique()

for i in unique:
    play_frame = test.loc[test['nflId'] == i]
    print(play_frame)
    ax.plot(play_frame['x'], play_frame['y'], marker='o', linestyle='-', color='blue')
# Out:
#             gameId  playId    nflId       displayName  frameId                        time  jerseyNumber club playDirection      x      y     s     a   dis       o    dir                event
# 250631  2022091101    3454  41227.0  Jadeveon Clowney        1  2022-09-11 15:46:20.599999          90.0  CLE         right  33.11  27.78  1.97  2.38  0.22  127.27  77.79                  NaN
# 250632  2022091101    3454  41227.0  Jadeveon Clowney        2  2022-09-11 15:46:20.700000          90.0  CLE         right  33.29  27.81  1.81  2.07  0.19  131.38  81.38                  NaN
# 250633  2022091101    3454  41227.0  Jadeveon Clowney        3  2022-09-11 15:46:20.799999          90.0  CLE         right  33.50  27.83  1.82  1.61  0.21  132.15  85.89                  NaN
# 250634  2022091101    3454  41227.0  Jadeveon Clowney        4  2022-09-11 15:46:20.900000          90.0  CLE         right  33.70  27.85  1.84  1.16  0.21  132.15  87.70                  NaN
# ...

# %%
games.head()
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0  2022090800    2022     1  09/08/2022        20:20:00           LA             BUF              10                 31
# 1  2022091100    2022     1  09/11/2022        13:00:00          ATL              NO              26                 27
# 2  2022091101    2022     1  09/11/2022        13:00:00          CAR             CLE              24                 26
# 3  2022091102    2022     1  09/11/2022        13:00:00          CHI              SF              19                 10
# 4  2022091103    2022     1  09/11/2022        13:00:00          CIN             PIT              20                 23

# %%
teamsAbbr = games['homeTeamAbbr'].unique()

# %%
first_week.loc[first_week['playId'] == 56]
# Out:
#             gameId  playId    nflId     displayName  frameId                        time  jerseyNumber      club playDirection          x          y     s     a   dis       o     dir         event
# 0       2022090800      56  35472.0  Rodger Saffold        1  2022-09-08 20:24:05.200000          76.0       BUF          left  88.370000  27.270000  1.62  1.15  0.16  231.74  147.90           NaN
# 1       2022090800      56  35472.0  Rodger Saffold        2  2022-09-08 20:24:05.299999          76.0       BUF          left  88.470000  27.130000  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2       2022090800      56  35472.0  Rodger Saffold        3  2022-09-08 20:24:05.400000          76.0       BUF          left  88.560000  27.010000  1.57  0.49  0.15  230.98  147.05           NaN
# 3       2022090800      56  35472.0  Rodger Saffold        4  2022-09-08 20:24:05.500000          76.0       BUF          left  88.640000  26.900000  1.44  0.89  0.14  232.38  145.42           NaN
# ...

# %%
first_week.head()
# Out:
#        gameId  playId    nflId     displayName  frameId                        time  jerseyNumber club playDirection      x      y     s     a   dis       o     dir         event
# 0  2022090800      56  35472.0  Rodger Saffold        1  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27  1.62  1.15  0.16  231.74  147.90           NaN
# 1  2022090800      56  35472.0  Rodger Saffold        2  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2  2022090800      56  35472.0  Rodger Saffold        3  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01  1.57  0.49  0.15  230.98  147.05           NaN
# 3  2022090800      56  35472.0  Rodger Saffold        4  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90  1.44  0.89  0.14  232.38  145.42           NaN
# ...

# %%
df = pd.merge(first_week, plays, on=['gameId', 'playId'], how='inner')

# %%
test = df.loc[(df['gameId'] == 2022090800) & (df['playId'] == 56)].to_csv('test.csv')

# %%
plays_positive = df.loc[(df['expectedPointsAdded'] > 0)]
plays_positive.sort_values(by='expectedPointsAdded')

frames = plays_positive.iloc[-6:]
frames
# Out:
#              gameId  playId  nflId displayName  frameId                        time  jerseyNumber      club playDirection          x          y     s     a   dis   o  dir   event  ballCarrierId ballCarrierDisplayName                                    playDescription  quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  yardlineNumber gameClock  preSnapHomeScore  preSnapVisitorScore passResult  passLength  penaltyYards  prePenaltyPlayResult  playResult playNullifiedByPenalty  absoluteYardlineNumber offenseFormation  defendersInTheBox  passProbability  preSnapHomeTeamWinProbability  preSnapVisitorTeamWinProbability  homeTeamWinProbabilityAdded  visitorTeamWinProbilityAdded  expectedPoints  expectedPointsAdded foulName1 foulName2  foulNFLId1  foulNFLId2
# ...

# %%
combine = pd.read_csv('/Users/benjaminzeisberg/university/cs171/final-project-correct/data/nfl-stats/combine.csv')

# %%
combine
# Out:
#        combineId  playerId  combineYear combinePosition  combineHeight  combineWeight  combineHand nameFirst     nameLast          nameFull position  collegeId    nflId         college  heightInches  weight         dob  ageAtDraft                                   playerProfileUrl       homeCity homeState homeCountry             highSchool           hsCity hsState  hsCountry  combineArm  combine40yd  combineVert  combineBench  combineShuttle  combineBroad  combine3cone  combine60ydShuttle  combineWonderlic
# ...

# %%
path = '/Users/benjaminzeisberg/university/cs171/final-project-correct/'

# %%
fumbles = pd.read_csv('/Users/benjaminzeisberg/university/cs171/final-project-correct//fumbles.csv')

# %%
fumbles
# Out:
#           fumId    playId  teamId  playerId fumPosition   fumType  fumOOB  fumTurnover  fumNull
# 0        800001         1    3800  20020185          RB    forced       0          0.0        0
# 1        800002        27    3200  20000239          FB    forced       0          0.0        0
# 2        800003        53    3200  20000199          QB  unforced       0          1.0        0
# 3        800004        56    3800  20020081          QB    forced       0          0.0        0
# 4        800005        84    3800  19970057          LB    forced       1          0.0        0
# ...         ...       ...     ...       ...         ...       ...     ...          ...      ...
# 14905  15242571  15084212    4600  20150069          WR    forced       1          0.0        0
# 14906  15242572  15084271    4900  20180038          RB    forced       0          1.0        0
# 14907  15242573  15084330     200  20080003          QB    forced       0          1.0        0
# ...

# %%
sacks = pd.read_csv('')
